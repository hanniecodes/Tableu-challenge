# %%
import pandas as pd

# %%
Jan= pd.read_csv("JC-202201-citibike-tripdata.csv")
Feb = pd.read_csv("JC-202202-citibike-tripdata.csv")
Mar=pd.read_csv("JC-202203-citibike-tripdata.csv")
Apr=pd.read_csv("JC-202204-citibike-tripdata.csv")
May=pd.read_csv("JC-202205-citibike-tripdata.csv")
Jun=pd.read_csv("JC-202206-citibike-tripdata.csv")

# %%
df_all_rows = pd.concat([Jan, Feb,Mar,Apr,May,Jun],ignore_index=True)
df_all_rows
# Out:
#                  ride_id  rideable_type           started_at  \
# 0       CA5837152804D4B5  electric_bike  2022-01-26 18:50:39
# 1       BA06A5E45B6601D2   classic_bike  2022-01-28 13:14:07
# 2       7B6827D7B9508D93   classic_bike  2022-01-10 19:55:13
# 3       6E5864EA6FCEC90D  electric_bike  2022-01-26 07:54:57
# 4       E24954255BBDE32D  electric_bike  2022-01-13 18:44:46
# ...                  ...            ...                  ...
# 356648  25AD34565A260732   classic_bike  2022-06-17 16:03:36
# 356649  8A4181FCE9439036   classic_bike  2022-06-25 14:14:26
# 356650  28C8501BCB596743  electric_bike  2022-06-04 08:57:04
# 356651  D28575BBFF3A0B57   classic_bike  2022-06-17 06:11:05
# 356652  A914FEF9390C201C  electric_bike  2022-06-02 18:15:17
#
#                    ended_at                            start_station_name  \
# 0       2022-01-26 18:51:53                          12 St & Sinatra Dr N
# 1       2022-01-28 13:20:23                              Essex Light Rail
# ...

# %%
df_all_rows.to_csv("6months_2022_bikeData.csv",index=False, header=True)
